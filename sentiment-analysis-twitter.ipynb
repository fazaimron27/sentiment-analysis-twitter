# %%
import json
from textblob import TextBlob

# %%
# load dataset
all_polarity = 0
with open('data/tweets.json', 'r') as dataset:
    tweets = json.load(dataset)
    for tweet in tweets:
        print('tweet: ', tweet['text'])

        analysis = TextBlob(tweet['text'])
        print(analysis.sentiment)
        all_polarity += analysis.polarity 

        print('')
    
if all_polarity/100 > 0:
    print(all_polarity/100)
    print('Positive')
else:
    print(all_polarity/100)
    print('Negative')
# Out:
# tweet:  RT @Coredao_Org: Bitcoin will play a very important role in the societal structure of this digital city. People know that Bitcoin is not on…
# Sentiment(polarity=0.26, subjectivity=0.5)
#
# tweet:  RT @BigSeanHarris: The correct method to smash buy #bitcoin when it dips 😂   https://t.co/AJxE4jiEUF
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  @RicherDadBlog Mr Bitcoin
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @turaxtoken: Take part info  our #Airdrop  Our listing iş coming soon. In July! Get ahead of everyone and earn some tokens. #Turax #Cryp…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @simplykashif: Many believe that Bitcoin is valuable because it has a limited supply of 21 million.  No, that does not make Bitcoin valu…
# Sentiment(polarity=0.2142857142857143, subjectivity=0.3214285714285714)
#
# tweet:  RT @avalancheavax: Good Bridging 🔺  Now that the Avalanche Bridge has added native support for Bitcoin, this technical overview breaks down…
# Sentiment(polarity=0.35, subjectivity=0.35000000000000003)
#
# tweet:  @zekekyle76 @Daniell71251047 @cameron You can’t kill something that’s not alive buddy
# Sentiment(polarity=-0.05, subjectivity=0.4)
#
# tweet:  RT @CryptoWhale: BREAKING: Iran announces they’re restricting #Bitcoin mining by cutting off electricity amid high energy consumption.   El…
# Sentiment(polarity=-0.21999999999999997, subjectivity=0.72)
#
# tweet:  RT @sunnydecree: The #Bitcoin network is the world’s most powerful lie detector. No wonder banks hate it.
# Sentiment(polarity=0.0, subjectivity=0.7999999999999999)
#
# tweet:  @CryptoWhale If you listened ten years ago and you bought bitcoin at $8 and HODL’d, then the recent drop to $21,000… https://t.co/edMUgCvw28
# Sentiment(polarity=0.0, subjectivity=0.125)
#
# tweet:  RT @SocialGood_Inc: 🏖️ Win $100 in $BTC 🏖️ Follow   RT this for a chance to win a cool $100 worth of #Bitcoin !! 🤩 We'll tag the lucky 32nd…
# Sentiment(polarity=0.5504166666666668, subjectivity=0.47666666666666674)
#
# tweet:  RT @BTC_Archive: #Bitcoin HODLers 💪 https://t.co/l2o7dZkMgY
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  @slater_exp @TheGRM1 @DannyDeVito "FACTS and LOGIC" says the bitcoin bro
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @TheBlock__: ICYMI: Avalanche introduces Bitcoin bridge as Core wallet feature https://t.co/L5L6lr6HIW
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @BTC_Archive: 💥UK: #Bitcoin and crypto could "make financial systems more transparent and reduce crime" - Government Minister,  Matt Han…
# Sentiment(polarity=0.25, subjectivity=0.25)
#
# tweet:  @GoldLeader89 IF you don’t know where the yield come from, YOU ARE THE YIELD !! https://t.co/6BJXgXOMV0
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @JoeCarlasare: People waiting for 10k #Bitcoin remind me of people waiting for 1k #Bitcoin in 2018.
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  #Bitcoin Last Price $21269 #BTC 🚀 Daily Indicators: •Variation since 00h00(UTC): +0.15% •MACD:  -MACD Line: -2506… https://t.co/YjMHNLK0q5
# Sentiment(polarity=0.0, subjectivity=0.03333333333333333)
#
# tweet:  RT @TheBlock__: ICYMI: Avalanche introduces Bitcoin bridge as Core wallet feature https://t.co/L5L6lr6HIW
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @BTCTN: #XRP, #AVAX near multi-week highs, following Friday's flurry. https://t.co/ui4WPBDi0s
# Sentiment(polarity=0.05, subjectivity=0.25)
#
# tweet:  @jordanfried But Bitcoin is down 32% since last year and CPI is up ~9%. Hasn’t purchasing power of the dollar far o… https://t.co/qtGuD5v7PG
# Sentiment(polarity=-0.018518518518518528, subjectivity=0.4518518518518519)
#
# tweet:  Shitcoins being shitcoins. #Bitcoin only. Period. https://t.co/dZ8XXoDXem
# Sentiment(polarity=0.0, subjectivity=1.0)
#
# tweet:  RT @Crypto_Saige: @SaitaKanOnline @SnoopDogg @LuckyRooToken The Next #100xgem Taking Over The Crypto Casino Industry.  Available in 2 Separ…
# Sentiment(polarity=0.2, subjectivity=0.2)
#
# tweet:  RT @Jayecane: rt + post your cashapp, PayPal, Bitcoin https://t.co/q7nl6N7ARq
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @avalancheavax: The Bitcoin bridging support leverages much of the same technology and design of the original Avalanche Bridge architect…
# Sentiment(polarity=0.19166666666666665, subjectivity=0.35833333333333334)
#
# tweet:  RT @BTCTN: It was recently revealed by developers that the public beta of #Shibarium, a #SHIB scaling solution, will launch in the third qu…
# Sentiment(polarity=0.0, subjectivity=0.10555555555555556)
#
# tweet:  RT @Coredao_Org: Bitcoin will play a very important role in the societal structure of this digital city. People know that Bitcoin is not on…
# Sentiment(polarity=0.26, subjectivity=0.5)
#
# tweet:  https://t.co/JNvedx7r19 Alternative I will show you in this video https://t.co/v335wXUtPW alternative website, that… https://t.co/1TU4i3SXIJ
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @SaitaKanOnline: Hello BIG @SnoopDogg if you like to gamble check out @LuckyRooToken itll be the biggest launch of 2022 exclusive to #Sa…
# Sentiment(polarity=0.0, subjectivity=0.1)
#
# tweet:  @Underrated_Dom @deyonte_btc Get *FREE* #CRYPTO (Free First, $10) You Must Deposit $100   Receive $BITCOIN$ | Sign-… https://t.co/KxKXIzMNW9
# Sentiment(polarity=0.35000000000000003, subjectivity=0.6444444444444445)
#
# tweet:  RT @avalancheavax: Good Bridging 🔺  Now that the Avalanche Bridge has added native support for Bitcoin, this technical overview breaks down…
# Sentiment(polarity=0.35, subjectivity=0.35000000000000003)
#
# tweet:  RT @JDxBruce: @TronixTrx @justinsuntron @trondao Airdrop @cctip_com draw 500000 Waifer 500  WaiferCoin @WaiferCoin FollowBack  YOU ARE GIVE…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  @RethinkinDollar Bitcoin is deflationary which means over time Bitcoin will overtake Gold as the worlds reserve ass… https://t.co/1q0SHO1SYq
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  @HansMlman  Hello my friend Help put a smile on the faces of the poor children of Gaza by donating or sharing the c… https://t.co/7QkVquZsTf
# Sentiment(polarity=-0.05000000000000002, subjectivity=0.35)
#
# tweet:  Sometimes I just want to buy a farm on like 20 acres and not worry about all this crap. #bitcoin, freedom, sovereig… https://t.co/Hu35LWnWvt
# Sentiment(polarity=-0.8, subjectivity=0.8)
#
# tweet:  RT @bitcoin_apex_rv: ~144 hours in. #Bitcoin  Can you spot the 丰 sign? Shot with LUMIX GX80. https://t.co/VV6up6Hd13
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @BTCTN: #XRP, #AVAX near multi-week highs, following Friday's flurry. https://t.co/ui4WPBDi0s
# Sentiment(polarity=0.05, subjectivity=0.25)
#
# tweet:  @zekekyle76 @Daniell71251047 @cameron A banana also has its own dna
# Sentiment(polarity=0.6, subjectivity=1.0)
#
# tweet:  RT @SaitaKanOnline: We love Lambo @LuckyRooToken   #LuckyRooToken #LuckyRoo #RooTroop #SaitaPro #Blockchain #Crypto #BSCGems #BSC #BNB #BNB…
# Sentiment(polarity=0.5, subjectivity=0.6)
#
# tweet:  RT @nanogamesio: Have you heard that TRX is now listed on https://t.co/3C773Pq77C !?🎰  🏆We will give $50 in $TRX to 2 winners in 48 hours t…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @r_topisto: #computerart #creativecoding #generativeart : #bitcoin #blockchain 's LAST Block, Height : 742226 [ See more on https://t.co…
# Sentiment(polarity=0.25, subjectivity=0.2833333333333333)
#
# tweet:  RT @turaxtoken: Take part info  our #Airdrop  Our listing iş coming soon. In July! Get ahead of everyone and earn some tokens. #Turax #Cryp…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @MonetaryFrame: A man who saves his time and effort in #Bitcoin can walk more certainly into the chaos of the future.  #MasculineFrame h…
# Sentiment(polarity=0.2380952380952381, subjectivity=0.3988095238095238)
#
# tweet:  #Bitcoin Price in last 3 hours: +0.24% change  Resistance around $21,400  Support around $21,200  Last $BTC Price:… https://t.co/bB1WrczRHE
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
#
# tweet:  🟩 Block 742227 ⛏ ⛏  📅 25th Jun 2022, 04:07:10 GMT  📣 856 tx with a value of 2,887.851 ₿ ($61.36m 🇺🇸)  📣 distributed… https://t.co/OBRHWleizA
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  What we learned as the series heads back to Tampa https://t.co/WBBjMn60wC  ▶️ https://t.co/NKkDBVS66N #Bitcoin #Sportsbook
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @turaxtoken: Take part info  our #Airdrop  Our listing iş coming soon. In July! Get ahead of everyone and earn some tokens. #Turax #Cryp…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @TheBitcoinConf: There are only three certainties:  1. Death 2. Taxes 3. 21 Million Bitcoin
# Sentiment(polarity=0.0, subjectivity=1.0)
#
# tweet:  RT @BTC_Archive: #Bitcoin HODLers 💪 https://t.co/l2o7dZkMgY
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  #Bitcoin mempool fees summary in the 60 seconds Mean = 5082 Median = 2304 Max = 100000 75th Quant = 3537 N.Obs = 10… https://t.co/BjOeJ5BICQ
# Sentiment(polarity=-0.3125, subjectivity=0.6875)
#
# tweet:  #Bitcoin mempool Tx summary in the last 60 seconds Mean = 2.40072 Median = 0.03084 Max = 154.27406 75th Quant = 0.3… https://t.co/Dfg1uV9rkC
# Sentiment(polarity=-0.15625, subjectivity=0.3770833333333333)
#
# tweet:  RT @ParikPatelCFA: “Buy when there’s blood in the streets, even if it’s your own” - person who bought #bitcoin at $60k
# Sentiment(polarity=0.6, subjectivity=1.0)
#
# tweet:  RT @sunnydecree: Money’s biggest problem isn’t the people in charge, it’s that there are people in charge.   #Bitcoin fixes this.
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @BTC_Archive: 💥SEC spot #Bitcoin ETF rejection "seems to me to be some element of corruption going on,” says Max Keiser
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @mikealfred: If Solana is going to have their own phone, #Bitcoin should have its own phone too. Who's building this?
# Sentiment(polarity=0.6, subjectivity=1.0)
#
# tweet:  Those who believe in Bitcoin also believe in cleverness. Invest wisely, make the clever choice now https://t.co/wlfShd3Ozt
# Sentiment(polarity=0.4333333333333333, subjectivity=0.8666666666666667)
#
# tweet:  @Ken72301226 @RobertKalish @VitalikButerin @songadaymann I’m aware , I prefer bitcoin in my portfolio. However Eth… https://t.co/7rUXjGYJGz
# Sentiment(polarity=0.25, subjectivity=0.25)
#
# tweet:  RT @SocialGood_Inc: 🏖️ Win $100 in $BTC 🏖️ Follow   RT this for a chance to win a cool $100 worth of #Bitcoin !! 🤩 We'll tag the lucky 32nd…
# Sentiment(polarity=0.5504166666666668, subjectivity=0.47666666666666674)
#
# tweet:  @AltGemHunter @PeakyInu PeakyInu  TO the  fucking koon @1goonrich @AltCryptoGems  #Peakyinu #peakygem… https://t.co/Ot4H8ATOfM
# Sentiment(polarity=-0.6, subjectivity=0.8)
#
# tweet:  RT @HukAleksandra: It’s the year 2030, Bitcoin crashed from $1.8M to $980k  The media: #Bitcoin is dead
# Sentiment(polarity=-0.2, subjectivity=0.4)
#
# tweet:  RT @AurelienOhayon: #BITCOIN A HUGE BULL RUN STARTS. https://t.co/PM5rWvUvlx
# Sentiment(polarity=0.4000000000000001, subjectivity=0.9)
#
# tweet:  When undertaking marriage, everyone must be the judge of his own thoughts, and take counsel from himself. - Francoi… https://t.co/ET4GToDNHh
# Sentiment(polarity=0.6, subjectivity=1.0)
#
# tweet:  RT @you_perez__: Central African Republic Accepts Bitcoin as Legal Tender. BTC is legal in this African country.
# Sentiment(polarity=0.08, subjectivity=0.13)
#
# tweet:  RT @SlingShotOn: When #Bitcoin reaches $40,000 again ( I know we are in a bear market right now)  I will buy a full computer gaming/crypto…
# Sentiment(polarity=0.31785714285714284, subjectivity=0.5428571428571429)
#
# tweet:  RT @satskeeper: Is it just me or did Satoshi, in a sly roundabout way, turn saving into an inalienable human right across all jurisdictions…
# Sentiment(polarity=0.14285714285714285, subjectivity=0.31785714285714284)
#
# tweet:  RT @HaroBuru: WL Registration Opened: https://t.co/G4JLQeLSc0  💟Star Collect Program (stake) 💟Real Collectibles 💟Haro Haro   🎉10X PREMIUM M…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  #Bitcoin: Bull Trap Or Breakout? A Chance To Reclaim ...  https://t.co/t4JV50pPFw  #BitcoinNews #BuyDoge… https://t.co/jdztlLXX5Q
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  https://t.co/s2suRYn0ke for sale.  #domains #domainnames #startup #startups #venturecapital #defi #technology… https://t.co/fDY4D22Dgj
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  📈📈📈LONG📈📈📈  💰#BEL 💰Entry Price = 0.8998 💰2022-06-25T05:28:00Z 💰Stop Loss =☎️LINK IN Profile $BEL #BTC #BITCOIN
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @BobLoukas: #bitcoin 3-month chart since inception.   Three 4-yr cycles.  All three topped at Months 33,34,34.  Two bottoms 46 and 46!…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @BTC_Archive: 💥BINANCE CEO: The number one value of #Bitcoin is that it has a limited supply.
# Sentiment(polarity=-0.07142857142857142, subjectivity=0.14285714285714285)
#
# tweet:  RT @TheBitcoinConf: There are only three certainties:  1. Death 2. Taxes 3. 21 Million Bitcoin
# Sentiment(polarity=0.0, subjectivity=1.0)
#
# tweet:  RT @BitcoinSapiens: If you have 0.029 #Bitcoin, you already have more in savings than most Americans. Keep stacking.
# Sentiment(polarity=0.5, subjectivity=0.5)
#
# tweet:  @AirdropStario Amazing project  #cryptocurrency #Airdrop #BSC #Bitcoin #USDT #Lithosphere #KaJLabs #JOT #Airdropstario
# Sentiment(polarity=0.6000000000000001, subjectivity=0.9)
#
# tweet:  RT @BTC_for_Freedom: - #bitcoin gets better the more you know about it - Fiat gets worse the more you know about it
# Sentiment(polarity=0.275, subjectivity=0.525)
#
# tweet:  RT @HukAleksandra: It’s the year 2030, Bitcoin crashed from $1.8M to $980k  The media: #Bitcoin is dead
# Sentiment(polarity=-0.2, subjectivity=0.4)
#
# tweet:  RT @JoshRoomsburg: New #Duet with @SalemIlese! 🔥  This is the #CryptoBoy Anthem!  @TrustWallet #TrustWallet ♥️  Leave a #Comment   #RT 👇  C…
# Sentiment(polarity=0.2130681818181818, subjectivity=0.45454545454545453)
#
# tweet:  Current #Bitcoin Price is $21296 #BTC #Crypto
# Sentiment(polarity=0.0, subjectivity=0.4)
#
# tweet:  White hat hacker attempts to recover 'millions' in lost Bitcoin, finds only $105 https://t.co/uWlsb976Fl
# Sentiment(polarity=0.0, subjectivity=0.5)
#
# tweet:  RT @BTC_Archive: 💥#Bitcoin miner capitulation has already occurred - CryptoQuant
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  @BTCs_BTC Bitcoin is just like evil spirit at the moment
# Sentiment(polarity=-1.0, subjectivity=1.0)
#
# tweet:  RT @FlylightsTech: #bitcoin rising We are reducing your #BNB Loss. We fixed the price. 1 BNB = 300 USDT 1 BNB = 37500 FLF Only Flylights ca…
# Sentiment(polarity=0.05, subjectivity=0.6)
#
# tweet:  We keep kicking ass and taking names ..another notch under Dogelon Mars belt tonight ..let’s do this!  #dogelonmars… https://t.co/4tWXEqaWat
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  @CryptoDonAlt @SBF_FTX Abrupt doesn’t mean over
# Sentiment(polarity=-0.21875, subjectivity=0.84375)
#
# tweet:  RT @StakerZero: Airdrop @cctip_com draw 5000 BTTNEW 450  #100XGem - Shill me your Gem 💎 🔥 🔥  #Bitcoin #SHIB #BTT #BabyDoge #TRX FollowBack
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  Very shortly #Saitama is going to take over the crypto space by storm!    Make sure you load up your bags and hold… https://t.co/UoMJ8yrMH4
# Sentiment(polarity=0.25, subjectivity=0.6394444444444445)
#
# tweet:  RT @turaxtoken: Take part info  our #Airdrop  Our listing iş coming soon. In July! Get ahead of everyone and earn some tokens. #Turax #Cryp…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  @Noahpinion if you are a smart person you willl notice it this is why bitcoin crashed   https://t.co/SwJ7cCrTka
# Sentiment(polarity=0.21428571428571427, subjectivity=0.6428571428571429)
#
# tweet:  RT @LuxuryBitcoin: ROLEX - DAYTONA for 6.60 #BTC Dial: Yellow gold and Black Case Size: 40 mm Case: Yellow Gold Bracelet: Yellow Gold Glass…
# Sentiment(polarity=-0.041666666666666664, subjectivity=0.10833333333333334)
#
# tweet:  #Bitcoin Last Price $21307 #BTC 🚀 Daily Indicators: •Variation since 00h00(UTC): +0.33% •MACD:  -MACD Line: -2503… https://t.co/w2rW301d9x
# Sentiment(polarity=0.0, subjectivity=0.03333333333333333)
#
# tweet:  @simplykashif Value of an asset class is decided on multiple factors, for bitcoin majorly the network effects and n… https://t.co/irQkGOva3d
# Sentiment(polarity=0.03125, subjectivity=0.25)
#
# tweet:  RT @TheBestBizzShow: “It seems that #bitcoin attracts a great number of very technically gifted people. It also seems to pull in people tha…
# Sentiment(polarity=0.65, subjectivity=0.875)
#
# tweet:  RT @stackhodler: Putin just gave a speech with massive implications for #Bitcoin and global macro.  We won't read a word of it in Western m…
# Sentiment(polarity=0.0, subjectivity=0.3333333333333333)
#
# tweet:  RT @naiivememe: #Bitcoin ma hometown https://t.co/8WRZ6h1eVv
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @YoloOptions: @TomerStrolight Out of these 7 traits of Money.  Bitcoin scores 6 Gold 4 Fiat 2 https://t.co/ctn5mnmIZS
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  @Dennis_Porter_ #Bitcoin will win either way
# Sentiment(polarity=0.8, subjectivity=0.4)
#
# tweet:  RT @BitcoinMagazine: Forbes: #Bitcoin can help solve the world's income inequality problem
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  Before claiming crypto is a fad do 30 hours of research  Really isn’t that long  Start off w reading the Bitcoin st… https://t.co/10ScoUiV8n
# Sentiment(polarity=0.07500000000000001, subjectivity=0.30000000000000004)
#
# tweet:  @CutieBabeGem15 @jiaeri88 @Crypto_Babe15 @PeakyInu PeakyInu  TO the  fucking koon @1goonrich @AltCryptoGems… https://t.co/1NqZddvwzM
# Sentiment(polarity=-0.6, subjectivity=0.8)
#
# tweet:  59,088 #BitcoinCash #BCH (6,617,817 USD) transferred with 0.0002 USD TX fee  $BCH TX: https://t.co/k67dANKBR9
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  The #Bitcoin market might be 'down' but us HODLers are out there holding the line and styling our statement 😎 https://t.co/iOH5c9sPGK
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
#
# tweet:  RT @SlingShotOn: When #Bitcoin reaches $40,000 again ( I know we are in a bear market right now)  I will buy a full computer gaming/crypto…
# Sentiment(polarity=0.31785714285714284, subjectivity=0.5428571428571429)
#
# tweet:  RT @HukAleksandra: It’s the year 2030, Bitcoin crashed from $1.8M to $980k  The media: #Bitcoin is dead
# Sentiment(polarity=-0.2, subjectivity=0.4)
#
# tweet:  @WhaleInfos @RealFlokiInu @BabyDogeCoin @bitgertbrise @EverRise #BitgertArmy 🥷🏼  ➡ Its A New Week, Are You Ready Fo… https://t.co/EJB7EovGcm
# Sentiment(polarity=0.16818181818181818, subjectivity=0.4772727272727273)
#
# tweet:  Saddle․Finance Creates New Standards for DeFi Trading https://t.co/SpDZl72SG6
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
#
# tweet:  Fear is just temporary but REGRET is forever take the risk now $buy #bitcoin
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  The price of Corn is a better predictor of the future Bitcoin price than any Micro variable in the crypto space.
# Sentiment(polarity=0.25, subjectivity=0.3125)
#
# tweet:  #Bitcoin Last Price $21302 #BTC 🚀 Daily Indicators: •Pivot Fibonacci:  -Support 1: 27775  -S2: 24635  -S3: 19554  -… https://t.co/FSNZ51IEok
# Sentiment(polarity=0.0, subjectivity=0.03333333333333333)
#
# tweet:  RT @SimonDixonTwitt: It’s really simple. If @CelsiusNetwork goes bankrupt #Bitcoin may save depositors in ten years if #TradFi does not sel…
# Sentiment(polarity=0.0, subjectivity=0.17857142857142858)
#
# tweet:  RT @HukAleksandra: It’s the year 2030, Bitcoin crashed from $1.8M to $980k  The media: #Bitcoin is dead
# Sentiment(polarity=-0.2, subjectivity=0.4)
#
# tweet:  @Cryptic_Maestro @PeakyInu PeakyInu  TO the  fucking koon @1goonrich @AltCryptoGems  #Peakyinu #peakygem… https://t.co/fvLnmqJOX0
# Sentiment(polarity=-0.6, subjectivity=0.8)
#
# tweet:  RT @ParikPatelCFA: “Buy when there’s blood in the streets, even if it’s your own” - person who bought #bitcoin at $60k
# Sentiment(polarity=0.6, subjectivity=1.0)
#
# tweet:  RT @sunnydecree: Money’s biggest problem isn’t the people in charge, it’s that there are people in charge.   #Bitcoin fixes this.
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @BTC_Archive: 💥SEC spot #Bitcoin ETF rejection "seems to me to be some element of corruption going on,” says Max Keiser
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @mikealfred: If Solana is going to have their own phone, #Bitcoin should have its own phone too. Who's building this?
# Sentiment(polarity=0.6, subjectivity=1.0)
#
# tweet:  Those who believe in Bitcoin also believe in cleverness. Invest wisely, make the clever choice now https://t.co/wlfShd3Ozt
# Sentiment(polarity=0.4333333333333333, subjectivity=0.8666666666666667)
#
# tweet:  @Ken72301226 @RobertKalish @VitalikButerin @songadaymann I’m aware , I prefer bitcoin in my portfolio. However Eth… https://t.co/7rUXjGYJGz
# Sentiment(polarity=0.25, subjectivity=0.25)
#
# tweet:  RT @SocialGood_Inc: 🏖️ Win $100 in $BTC 🏖️ Follow   RT this for a chance to win a cool $100 worth of #Bitcoin !! 🤩 We'll tag the lucky 32nd…
# Sentiment(polarity=0.5504166666666668, subjectivity=0.47666666666666674)
#
# tweet:  @AltGemHunter @PeakyInu PeakyInu  TO the  fucking koon @1goonrich @AltCryptoGems  #Peakyinu #peakygem… https://t.co/Ot4H8ATOfM
# Sentiment(polarity=-0.6, subjectivity=0.8)
#
# tweet:  RT @HukAleksandra: It’s the year 2030, Bitcoin crashed from $1.8M to $980k  The media: #Bitcoin is dead
# Sentiment(polarity=-0.2, subjectivity=0.4)
#
# tweet:  RT @AurelienOhayon: #BITCOIN A HUGE BULL RUN STARTS. https://t.co/PM5rWvUvlx
# Sentiment(polarity=0.4000000000000001, subjectivity=0.9)
#
# tweet:  When undertaking marriage, everyone must be the judge of his own thoughts, and take counsel from himself. - Francoi… https://t.co/ET4GToDNHh
# Sentiment(polarity=0.6, subjectivity=1.0)
#
# tweet:  RT @you_perez__: Central African Republic Accepts Bitcoin as Legal Tender. BTC is legal in this African country.
# Sentiment(polarity=0.08, subjectivity=0.13)
#
# tweet:  RT @SlingShotOn: When #Bitcoin reaches $40,000 again ( I know we are in a bear market right now)  I will buy a full computer gaming/crypto…
# Sentiment(polarity=0.31785714285714284, subjectivity=0.5428571428571429)
#
# tweet:  RT @satskeeper: Is it just me or did Satoshi, in a sly roundabout way, turn saving into an inalienable human right across all jurisdictions…
# Sentiment(polarity=0.14285714285714285, subjectivity=0.31785714285714284)
#
# tweet:  RT @HaroBuru: WL Registration Opened: https://t.co/G4JLQeLSc0  💟Star Collect Program (stake) 💟Real Collectibles 💟Haro Haro   🎉10X PREMIUM M…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  #Bitcoin: Bull Trap Or Breakout? A Chance To Reclaim ...  https://t.co/t4JV50pPFw  #BitcoinNews #BuyDoge… https://t.co/jdztlLXX5Q
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  https://t.co/s2suRYn0ke for sale.  #domains #domainnames #startup #startups #venturecapital #defi #technology… https://t.co/fDY4D22Dgj
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  📈📈📈LONG📈📈📈  💰#BEL 💰Entry Price = 0.8998 💰2022-06-25T05:28:00Z 💰Stop Loss =☎️LINK IN Profile $BEL #BTC #BITCOIN
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @BobLoukas: #bitcoin 3-month chart since inception.   Three 4-yr cycles.  All three topped at Months 33,34,34.  Two bottoms 46 and 46!…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @BTC_Archive: 💥BINANCE CEO: The number one value of #Bitcoin is that it has a limited supply.
# Sentiment(polarity=-0.07142857142857142, subjectivity=0.14285714285714285)
#
# tweet:  RT @TheBitcoinConf: There are only three certainties:  1. Death 2. Taxes 3. 21 Million Bitcoin
# Sentiment(polarity=0.0, subjectivity=1.0)
#
# tweet:  RT @BitcoinSapiens: If you have 0.029 #Bitcoin, you already have more in savings than most Americans. Keep stacking.
# Sentiment(polarity=0.5, subjectivity=0.5)
#
# tweet:  @AirdropStario Amazing project  #cryptocurrency #Airdrop #BSC #Bitcoin #USDT #Lithosphere #KaJLabs #JOT #Airdropstario
# Sentiment(polarity=0.6000000000000001, subjectivity=0.9)
#
# tweet:  RT @BTC_for_Freedom: - #bitcoin gets better the more you know about it - Fiat gets worse the more you know about it
# Sentiment(polarity=0.275, subjectivity=0.525)
#
# tweet:  RT @HukAleksandra: It’s the year 2030, Bitcoin crashed from $1.8M to $980k  The media: #Bitcoin is dead
# Sentiment(polarity=-0.2, subjectivity=0.4)
#
# tweet:  RT @JoshRoomsburg: New #Duet with @SalemIlese! 🔥  This is the #CryptoBoy Anthem!  @TrustWallet #TrustWallet ♥️  Leave a #Comment   #RT 👇  C…
# Sentiment(polarity=0.2130681818181818, subjectivity=0.45454545454545453)
#
# tweet:  Pretty much nothing in the news about this. I guess they don't want to give anyone any ideas now that it's spreadin… https://t.co/UroScC7svP
# Sentiment(polarity=0.225, subjectivity=0.6)
#
# tweet:  @Emillgrisolia Yeah I stayed up for something else but also didn’t sleep and watch Bitcoin on phone. It’s basically… https://t.co/Pg8aDxxCwB
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @BitcoinMagazine: #Bitcoin is freedom money https://t.co/pYadZdCKPi
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @SlingShotOn: When #Bitcoin reaches $40,000 again ( I know we are in a bear market right now)  I will buy a full computer gaming/crypto…
# Sentiment(polarity=0.31785714285714284, subjectivity=0.5428571428571429)
#
# tweet:  RT @skwp: . @GoldmanSachs should buy $2B of bitcoin instead of a failed crypto lender. This is financial advice. I am available for CFO and…
# Sentiment(polarity=-0.033333333333333326, subjectivity=0.2333333333333333)
#
# tweet:  RT @DaikiFintech: DFTC is all about Fintech and one must grab the opportunity to understand its importance to their benefits! ⚡ ___ Know mo…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @stackhodler: Putin just gave a speech with massive implications for #Bitcoin and global macro.  We won't read a word of it in Western m…
# Sentiment(polarity=0.0, subjectivity=0.3333333333333333)
#
# tweet:  RT @FlylightsTech: 🔥NOW ON PRESALE🔥  #presale stage 3 is running out fast. 91% complete. Don't miss the opportunity to buy early.  🔴 Stage…
# Sentiment(polarity=0.13333333333333333, subjectivity=0.43333333333333335)
#
# tweet:  RT @Giveawayquinn: $60 | 360 mins  ⏰  RT • LIKE • FOLLOW  @Nftdunyas1 @Giveawayquinn  #Bitcoin #NFTGiveaway #NFTCommunity #NFTshill
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @pete_rizzo_: ✨ El Salvador President announcing national #Bitcoin giveaway exactly 1 year ago.   The largest-ever distribution of free…
# Sentiment(polarity=0.25, subjectivity=0.25)
#
# tweet:  @saylor If someone absolutely new come in  to crypto and wanna invest,it will be never bitcoin....i pleased someone… https://t.co/24AQzHNfZz
# Sentiment(polarity=0.3181818181818182, subjectivity=0.7272727272727273)
#
# tweet:  RT @coryklippsten: The best way to buy bitcoin for anyone with steady cash inflow is via an Automatic Recurring Purchase Plan, (aka “Auto-D…
# Sentiment(polarity=0.5833333333333334, subjectivity=0.4)
#
# tweet:  @bitcoin_is_hope @SBF_FTX Having been does though
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @BitcoinBF: Let's give away some Bitcoin on this Friday. I'll randomly choose one person who Retweets this and send them $25 in BTC.  Mu…
# Sentiment(polarity=-0.5, subjectivity=0.5)
#
# tweet:  RT @Nneuman: Get ready for years of bankruptcy proceedings before any customers receive even a fraction of the bitcoin they held at Celsius…
# Sentiment(polarity=0.2, subjectivity=0.5)
#
# tweet:  RT @turaxtoken: Take part info  our #Airdrop  Our listing iş coming soon. In July! Get ahead of everyone and earn some tokens. #Turax #Cryp…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @MotorUp2: Yo. #Crypto fool. Time to jump onboard #xRhodium,#XRC. Get off your #Bitcoin butt and do some research.  https://t.co/C6dqKwV…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  @kirakfw I lost my coinbase wallet with my bitcoin and meta mask + I need a sugar mommy + I need a sugar daddy + he… https://t.co/YBTyI4U4wZ
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @KapitalDAO: The price of bitcoin fell below $20,000, a figure closely watched by cryptocurrency aficionados, as a violent selloff in cr…
# Sentiment(polarity=-0.8, subjectivity=1.0)
#
# tweet:  @SharksCoins @PeakyInu PeakyInu  TO the  fucking koon @1goonrich @AltCryptoGems  #Peakyinu #peakygem #Peakymoonshot… https://t.co/EvqVKRKtwg
# Sentiment(polarity=-0.6, subjectivity=0.8)
#
# tweet:  RT @FlylightsTech: #Flylights FL104 #deliverydrone  Nature Friendly The FL 104’s upper section provides approximately 10% energy saving on…
# Sentiment(polarity=-0.00833333333333334, subjectivity=0.3666666666666667)
#
# tweet:  RT @YoloOptions: @TomerStrolight Out of these 7 traits of Money.  Bitcoin scores 6 Gold 4 Fiat 2 https://t.co/ctn5mnmIZS
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  @Dennis_Porter_ #Bitcoin will win either way
# Sentiment(polarity=0.8, subjectivity=0.4)
#
# tweet:  RT @BitcoinMagazine: Forbes: #Bitcoin can help solve the world's income inequality problem
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  Before claiming crypto is a fad do 30 hours of research  Really isn’t that long  Start off w reading the Bitcoin st… https://t.co/10ScoUiV8n
# Sentiment(polarity=0.07500000000000001, subjectivity=0.30000000000000004)
#
# tweet:  @CutieBabeGem15 @jiaeri88 @Crypto_Babe15 @PeakyInu PeakyInu  TO the  fucking koon @1goonrich @AltCryptoGems… https://t.co/1NqZddvwzM
# Sentiment(polarity=-0.6, subjectivity=0.8)
#
# tweet:  59,088 #BitcoinCash #BCH (6,617,817 USD) transferred with 0.0002 USD TX fee  $BCH TX: https://t.co/k67dANKBR9
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  The #Bitcoin market might be 'down' but us HODLers are out there holding the line and styling our statement 😎 https://t.co/iOH5c9sPGK
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
#
# tweet:  RT @SlingShotOn: When #Bitcoin reaches $40,000 again ( I know we are in a bear market right now)  I will buy a full computer gaming/crypto…
# Sentiment(polarity=0.31785714285714284, subjectivity=0.5428571428571429)
#
# tweet:  RT @HukAleksandra: It’s the year 2030, Bitcoin crashed from $1.8M to $980k  The media: #Bitcoin is dead
# Sentiment(polarity=-0.2, subjectivity=0.4)
#
# tweet:  53,422 #BitcoinCash #BCH (5,983,225 USD) transferred with 0.0002 USD TX fee  $BCH TX: https://t.co/UcH6eS6mXn
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  @WhaleInfos @RealFlokiInu @BabyDogeCoin @bitgertbrise @EverRise #BitgertArmy 🥷🏼  ➡ Its A New Week, Are You Ready Fo… https://t.co/EJB7EovGcm
# Sentiment(polarity=0.16818181818181818, subjectivity=0.4772727272727273)
#
# tweet:  Saddle․Finance Creates New Standards for DeFi Trading https://t.co/SpDZl72SG6
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
#
# tweet:  Fear is just temporary but REGRET is forever take the risk now $buy #bitcoin
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  The price of Corn is a better predictor of the future Bitcoin price than any Micro variable in the crypto space.
# Sentiment(polarity=0.25, subjectivity=0.3125)
#
# tweet:  #Bitcoin Last Price $21302 #BTC 🚀 Daily Indicators: •Pivot Fibonacci:  -Support 1: 27775  -S2: 24635  -S3: 19554  -… https://t.co/FSNZ51IEok
# Sentiment(polarity=0.0, subjectivity=0.03333333333333333)
#
# tweet:  RT @SimonDixonTwitt: It’s really simple. If @CelsiusNetwork goes bankrupt #Bitcoin may save depositors in ten years if #TradFi does not sel…
# Sentiment(polarity=0.0, subjectivity=0.17857142857142858)
#
# tweet:  RT @HukAleksandra: It’s the year 2030, Bitcoin crashed from $1.8M to $980k  The media: #Bitcoin is dead
# Sentiment(polarity=-0.2, subjectivity=0.4)
#
# tweet:  @Cryptic_Maestro @PeakyInu PeakyInu  TO the  fucking koon @1goonrich @AltCryptoGems  #Peakyinu #peakygem… https://t.co/fvLnmqJOX0
# Sentiment(polarity=-0.6, subjectivity=0.8)
#
# tweet:  RT @ParikPatelCFA: “Buy when there’s blood in the streets, even if it’s your own” - person who bought #bitcoin at $60k
# Sentiment(polarity=0.6, subjectivity=1.0)
#
# tweet:  RT @sunnydecree: Money’s biggest problem isn’t the people in charge, it’s that there are people in charge.   #Bitcoin fixes this.
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @BTC_Archive: 💥SEC spot #Bitcoin ETF rejection "seems to me to be some element of corruption going on,” says Max Keiser
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @mikealfred: If Solana is going to have their own phone, #Bitcoin should have its own phone too. Who's building this?
# Sentiment(polarity=0.6, subjectivity=1.0)
#
# tweet:  Those who believe in Bitcoin also believe in cleverness. Invest wisely, make the clever choice now https://t.co/wlfShd3Ozt
# Sentiment(polarity=0.4333333333333333, subjectivity=0.8666666666666667)
#
# tweet:  @Ken72301226 @RobertKalish @VitalikButerin @songadaymann I’m aware , I prefer bitcoin in my portfolio. However Eth… https://t.co/7rUXjGYJGz
# Sentiment(polarity=0.25, subjectivity=0.25)
#
# tweet:  RT @SocialGood_Inc: 🏖️ Win $100 in $BTC 🏖️ Follow   RT this for a chance to win a cool $100 worth of #Bitcoin !! 🤩 We'll tag the lucky 32nd…
# Sentiment(polarity=0.5504166666666668, subjectivity=0.47666666666666674)
#
# tweet:  @AltGemHunter @PeakyInu PeakyInu  TO the  fucking koon @1goonrich @AltCryptoGems  #Peakyinu #peakygem… https://t.co/Ot4H8ATOfM
# Sentiment(polarity=-0.6, subjectivity=0.8)
#
# tweet:  RT @HukAleksandra: It’s the year 2030, Bitcoin crashed from $1.8M to $980k  The media: #Bitcoin is dead
# Sentiment(polarity=-0.2, subjectivity=0.4)
#
# tweet:  RT @AurelienOhayon: #BITCOIN A HUGE BULL RUN STARTS. https://t.co/PM5rWvUvlx
# Sentiment(polarity=0.4000000000000001, subjectivity=0.9)
#
# tweet:  When undertaking marriage, everyone must be the judge of his own thoughts, and take counsel from himself. - Francoi… https://t.co/ET4GToDNHh
# Sentiment(polarity=0.6, subjectivity=1.0)
#
# tweet:  RT @you_perez__: Central African Republic Accepts Bitcoin as Legal Tender. BTC is legal in this African country.
# Sentiment(polarity=0.08, subjectivity=0.13)
#
# tweet:  RT @SlingShotOn: When #Bitcoin reaches $40,000 again ( I know we are in a bear market right now)  I will buy a full computer gaming/crypto…
# Sentiment(polarity=0.31785714285714284, subjectivity=0.5428571428571429)
#
# tweet:  RT @satskeeper: Is it just me or did Satoshi, in a sly roundabout way, turn saving into an inalienable human right across all jurisdictions…
# Sentiment(polarity=0.14285714285714285, subjectivity=0.31785714285714284)
#
# tweet:  RT @CWA_warriors: 🎯 #MEMECONTEST 📸  🥇1st: 100 usd 🥈2nd: 60 usd 🥉3rd: 30 usd  1️⃣ Follow @CWA_warriors 2️⃣ Like RT   Tag 3 friends 3️⃣ Join…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @BitcoinFear: Bitcoin Fear and Greed Index is 14 ~ Extreme Fear Current price: $21,255 https://t.co/Y8F8XAIpy8
# Sentiment(polarity=-0.0625, subjectivity=0.7)
#
# tweet:  @CharlesSchwab That baby be sayin: Buy the Fu¢K1ng dip, dad! Bitcoin only
# Sentiment(polarity=0.0, subjectivity=1.0)
#
# tweet:  RT @CryptoBusy: We’ve been loving giving back to the #crypto community in 2022 so far, so let’s make a fun new bet! 🚀  If #Bitcoin doesn’t…
# Sentiment(polarity=0.23409090909090907, subjectivity=0.5209090909090909)
#
# tweet:  RT @CryptoWhale: #Bitcoin maximalists spent the last 10+ years predicting a recession, claiming it would cause Bitcoin to shoot to millions…
# Sentiment(polarity=-0.05, subjectivity=0.08333333333333334)
#
# tweet:  RT @rovercrc: Everyone who will wait to buy #Bitcoin below $10,000 will end up buying $BTC above $100,000.
# Sentiment(polarity=0.0, subjectivity=0.1)
#
# tweet:  RT @refs4me: #betfury is one of the top #bitcoin casinos - You can get daily #cash back simply holding #bfgtoken in your account wallet.  #…
# Sentiment(polarity=0.125, subjectivity=0.2142857142857143)
#
# tweet:  @WHALEGEMS1000X @AltGemHunter @PeakyInu @1goonrich @AltCryptoGems Follow @Inv016 For best bitcoin charts n Updates
# Sentiment(polarity=1.0, subjectivity=0.3)
#
# tweet:  #Bitcoin soon 😎 https://t.co/XKkgc3nN5H
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @KapitalDAO: Peter Brandt predicted 2018's crypto winter. If #Bitcoin doesn't reach $32,000, he says it might fall below $13,000.  Brand…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  @AltGemHunter @Starbots_game @PeakyInu PeakyInu  TO the  fucking koon @1goonrich @AltCryptoGems  #Peakyinu… https://t.co/6EFOLHsE5o
# Sentiment(polarity=-0.6, subjectivity=0.8)
#
# tweet:  Bitcoin gearing up for some move imo
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @BTC_Archive: 💥BINANCE CEO: The number one value of #Bitcoin is that it has a limited supply.
# Sentiment(polarity=-0.07142857142857142, subjectivity=0.14285714285714285)
#
# tweet:  Success is not always what you see. @MauriceHoefgen  #Bitcoin https://t.co/6F5BEcTQWf
# Sentiment(polarity=0.3, subjectivity=0.0)
#
# tweet:  RT @HEXcryptoo: 🚨 https://t.co/0Uw8WEaGXg is here! For all HEX holders, we've launched a big community AirDrop.  🔥The more you hold, the mo…
# Sentiment(polarity=0.25, subjectivity=0.3)
#
# tweet:  RT @refs4me: #adsterra is one of the top #advertising networks and allows you to buy ads on tens of thousands of sites.  Earn #bitcoin and…
# Sentiment(polarity=0.5, subjectivity=0.5)
#
# tweet:  @CutieBabeGem15 @PeakyInu PeakyInu  TO the  fucking koon @1goonrich @AltCryptoGems  #Peakyinu #peakygem… https://t.co/VSTvPVOf7V
# Sentiment(polarity=-0.6, subjectivity=0.8)
#
# tweet:  @Chris01225 @Ken72301226 @RobertKalish @VitalikButerin @songadaymann Follow @Inv016 For best bitcoin charts n Updates
# Sentiment(polarity=1.0, subjectivity=0.3)
#
# tweet:  RT @Rhian_Pw: Buy #Bitcoin, you will thank me 3 years from now.
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @DarinFeinstein: Transaction Fee FUD  The #Bitcoin Network is performing as designed  #Bitcoin tsx fees  2011 $29,960 2012 $64,400 2013…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  Ethereum will FLIP Bitcoin   CARDANO to be #1 Crypto! https://t.co/e4WPWlbLDS
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  #Bitcoin is not confirming it's movement right now if it touches 22k it's gonna pump hardly and atm 21.1k is reject… https://t.co/w7pwRP9zg7
# Sentiment(polarity=-0.0029761904761904934, subjectivity=0.5386904761904762)
#
# tweet:  RT @turaxtoken: Take part info  our #Airdrop  Our listing iş coming soon. In July! Get ahead of everyone and earn some tokens. #Turax #Cryp…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  Pretty much nothing in the news about this. I guess they don't want to give anyone any ideas now that it's spreadin… https://t.co/UroScC7svP
# Sentiment(polarity=0.225, subjectivity=0.6)
#
# tweet:  @Emillgrisolia Yeah I stayed up for something else but also didn’t sleep and watch Bitcoin on phone. It’s basically… https://t.co/Pg8aDxxCwB
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @BitcoinMagazine: #Bitcoin is freedom money https://t.co/pYadZdCKPi
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @SlingShotOn: When #Bitcoin reaches $40,000 again ( I know we are in a bear market right now)  I will buy a full computer gaming/crypto…
# Sentiment(polarity=0.31785714285714284, subjectivity=0.5428571428571429)
#
# tweet:  RT @skwp: . @GoldmanSachs should buy $2B of bitcoin instead of a failed crypto lender. This is financial advice. I am available for CFO and…
# Sentiment(polarity=-0.033333333333333326, subjectivity=0.2333333333333333)
#
# tweet:  RT @DaikiFintech: DFTC is all about Fintech and one must grab the opportunity to understand its importance to their benefits! ⚡ ___ Know mo…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @stackhodler: Putin just gave a speech with massive implications for #Bitcoin and global macro.  We won't read a word of it in Western m…
# Sentiment(polarity=0.0, subjectivity=0.3333333333333333)
#
# tweet:  RT @FlylightsTech: 🔥NOW ON PRESALE🔥  #presale stage 3 is running out fast. 91% complete. Don't miss the opportunity to buy early.  🔴 Stage…
# Sentiment(polarity=0.13333333333333333, subjectivity=0.43333333333333335)
#
# tweet:  RT @Giveawayquinn: $60 | 360 mins  ⏰  RT • LIKE • FOLLOW  @Nftdunyas1 @Giveawayquinn  #Bitcoin #NFTGiveaway #NFTCommunity #NFTshill
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @pete_rizzo_: ✨ El Salvador President announcing national #Bitcoin giveaway exactly 1 year ago.   The largest-ever distribution of free…
# Sentiment(polarity=0.25, subjectivity=0.25)
#
# tweet:  @saylor If someone absolutely new come in  to crypto and wanna invest,it will be never bitcoin....i pleased someone… https://t.co/24AQzHNfZz
# Sentiment(polarity=0.3181818181818182, subjectivity=0.7272727272727273)
#
# tweet:  RT @coryklippsten: The best way to buy bitcoin for anyone with steady cash inflow is via an Automatic Recurring Purchase Plan, (aka “Auto-D…
# Sentiment(polarity=0.5833333333333334, subjectivity=0.4)
#
# tweet:  @bitcoin_is_hope @SBF_FTX Having been does though
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @BitcoinBF: Let's give away some Bitcoin on this Friday. I'll randomly choose one person who Retweets this and send them $25 in BTC.  Mu…
# Sentiment(polarity=-0.5, subjectivity=0.5)
#
# tweet:  RT @Nneuman: Get ready for years of bankruptcy proceedings before any customers receive even a fraction of the bitcoin they held at Celsius…
# Sentiment(polarity=0.2, subjectivity=0.5)
#
# tweet:  RT @turaxtoken: Take part info  our #Airdrop  Our listing iş coming soon. In July! Get ahead of everyone and earn some tokens. #Turax #Cryp…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @MotorUp2: Yo. #Crypto fool. Time to jump onboard #xRhodium,#XRC. Get off your #Bitcoin butt and do some research.  https://t.co/C6dqKwV…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  @kirakfw I lost my coinbase wallet with my bitcoin and meta mask + I need a sugar mommy + I need a sugar daddy + he… https://t.co/YBTyI4U4wZ
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  RT @KapitalDAO: The price of bitcoin fell below $20,000, a figure closely watched by cryptocurrency aficionados, as a violent selloff in cr…
# Sentiment(polarity=-0.8, subjectivity=1.0)
#
# tweet:  @SharksCoins @PeakyInu PeakyInu  TO the  fucking koon @1goonrich @AltCryptoGems  #Peakyinu #peakygem #Peakymoonshot… https://t.co/EvqVKRKtwg
# Sentiment(polarity=-0.6, subjectivity=0.8)
#
# tweet:  RT @FlylightsTech: #Flylights FL104 #deliverydrone  Nature Friendly The FL 104’s upper section provides approximately 10% energy saving on…
# Sentiment(polarity=-0.00833333333333334, subjectivity=0.3666666666666667)
#
# tweet:  RT @YoloOptions: @TomerStrolight Out of these 7 traits of Money.  Bitcoin scores 6 Gold 4 Fiat 2 https://t.co/ctn5mnmIZS
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  @Dennis_Porter_ #Bitcoin will win either way
# Sentiment(polarity=0.8, subjectivity=0.4)
#
# tweet:  RT @BitcoinMagazine: Forbes: #Bitcoin can help solve the world's income inequality problem
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  Before claiming crypto is a fad do 30 hours of research  Really isn’t that long  Start off w reading the Bitcoin st… https://t.co/10ScoUiV8n
# Sentiment(polarity=0.07500000000000001, subjectivity=0.30000000000000004)
#
# tweet:  @CutieBabeGem15 @jiaeri88 @Crypto_Babe15 @PeakyInu PeakyInu  TO the  fucking koon @1goonrich @AltCryptoGems… https://t.co/1NqZddvwzM
# Sentiment(polarity=-0.6, subjectivity=0.8)
#
# tweet:  59,088 #BitcoinCash #BCH (6,617,817 USD) transferred with 0.0002 USD TX fee  $BCH TX: https://t.co/k67dANKBR9
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  The #Bitcoin market might be 'down' but us HODLers are out there holding the line and styling our statement 😎 https://t.co/iOH5c9sPGK
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
#
# tweet:  RT @SlingShotOn: When #Bitcoin reaches $40,000 again ( I know we are in a bear market right now)  I will buy a full computer gaming/crypto…
# Sentiment(polarity=0.31785714285714284, subjectivity=0.5428571428571429)
#
# tweet:  RT @HukAleksandra: It’s the year 2030, Bitcoin crashed from $1.8M to $980k  The media: #Bitcoin is dead
# Sentiment(polarity=-0.2, subjectivity=0.4)
#
# tweet:  53,422 #BitcoinCash #BCH (5,983,225 USD) transferred with 0.0002 USD TX fee  $BCH TX: https://t.co/UcH6eS6mXn
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# tweet:  @WhaleInfos @RealFlokiInu @BabyDogeCoin @bitgertbrise @EverRise #BitgertArmy 🥷🏼  ➡ Its A New Week, Are You Ready Fo… https://t.co/EJB7EovGcm
# Sentiment(polarity=0.16818181818181818, subjectivity=0.4772727272727273)
#
# tweet:  Saddle․Finance Creates New Standards for DeFi Trading https://t.co/SpDZl72SG6
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
#
# 0.1786879208754209
# Positive
